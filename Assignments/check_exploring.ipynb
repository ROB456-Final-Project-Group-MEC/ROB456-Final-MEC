# %%
# Initialize Otter
import otter
grader = otter.Notebook("check_exploring.ipynb")

# %% [markdown]
# # Instructions
#
# This assignment lets you both define a strategy for picking the next point to explore and determine how you want to chop up a full path into way points. You'll need **path_planning.py** and **exploring.py** as well (for calculating the paths)
#
# Note that there isn't a "right" answer for any of these. This is (mostly) a light-weight way to check your code for obvious problems before trying it in ROS. It's set up to make it easy to download a map and try some robot starting/ending points
#
# Given to you:
# - Image handling
# - plotting
# - Some structure for keeping/changing waypoints and converting to/from the map to the robot's coordinate space
#
# Slides: https://docs.google.com/presentation/d/1tOUGoNDbzQeuzRwG-kJ-ipqDsCy3ABkIvNEdFmozRT8/edit?usp=sharing

# %%
# The ever-present numpy and matplot lib
import numpy as np
import os

# %%
# These commands will force JN to actually re-load the external file when you re-execute the import command
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Run exploring a SLAM map

# %%
try:
    from path_planning import dijkstra, plot_with_path, open_image
    from exploring import find_all_possible_goals, find_best_point, plot_with_explore_points, find_waypoints, test_unseen, test_best
except Exception as e:
    print(f" EZ got here: {e}")
    cur_dir = os.getcwd()
    if "Assignments" in cur_dir or "Skills" in cur_dir:
        path_planning_dir = "../ros_ws/src/lab3/lab3"

        os.chdir(path_planning_dir)
        from path_planning import dijkstra, plot_with_path, open_image
        from exploring import find_all_possible_goals, find_best_point, plot_with_explore_points, find_waypoints, test_unseen, test_best, plot_image, plot_goal_pts_explore_pts, find_best_points
        os.chdir(cur_dir)

# r_dir = os.getcwd()
# if "Assignments" in cur_dir or "Skills" in cur_dir:
#     path_planning_dir = "../ros_ws/src/lab3/lab3"

#     os.chdir(path_planning_dir)
#     from path_planning import dijkstra, plot_with_path, open_image
#     from exploring import find_all_possible_goals, find_best_point, plot_with_explore_points, find_waypoints, test_unseen, test_best, plot_image, plot_goal_pts_explore_pts, find_best_points
#     os.chdir(cur_dir)
# Out:
#  EZ got here: No module named 'path_planning'

# %%
# You can use map or initial
# _, im_thresh = open_image("map.pgm")
im_thresh, _ = open_image("explored_map.pgm")
# print(im_thresh.shape)
# plot_image(im_thresh)
# Split into two pieces - find all of the points that are adjacent to an unknown area and a visible area. The
#. next question will pick the "best" one
all_unseen = find_all_possible_goals(im_thresh)
print(all_unseen)
assert test_unseen(im_thresh, all_unseen)

# Note: This can be a little slow (it's drawing a lot of little points)
zoom = 1.0
plot_with_explore_points(im_thresh, zoom=1.0, robot_loc=None, explore_points=all_unseen, best_pt=None)
# Out:
# /home/elliot/Desktop/CodingProjects/ROB456-Final-MEC/Assignments
# [(np.int64(127), np.int64(177)), (np.int64(126), np.int64(178)), (np.int64(127), np.int64(178)), (np.int64(128), np.int64(178)), (np.int64(127), np.int64(179)), (np.int64(123), np.int64(182)), (np.int64(132), np.int64(182)), (np.int64(122), np.int64(183)), (np.int64(123), np.int64(183)), (np.int64(124), np.int64(183)), (np.int64(131), np.int64(183)), (np.int64(132), np.int64(183)), (np.int64(133), np.int64(183)), (np.int64(123), np.int64(184)), (np.int64(126), np.int64(184)), (np.int64(132), np.int64(184)), (np.int64(133), np.int64(184)), (np.int64(134), np.int64(184)), (np.int64(114), np.int64(185)), (np.int64(125), np.int64(185)), (np.int64(126), np.int64(185)), (np.int64(127), np.int64(185)), (np.int64(131),
# %%
grader.check("unknown_area")
# Out:
# unknown_area results: All test cases passed!

# %%
# to visualize areas of interst in exploring:
robot_start_loc = (60, 40)
better_pts = find_best_points(im_thresh, all_unseen, robot_loc=robot_start_loc)
print(better_pts)
plot_with_explore_points(im_thresh, zoom=1.0, robot_loc=None, explore_points=better_pts, best_pt=None)
# Out:
# [(np.int64(29), np.int64(267)), (np.int64(127), np.int64(189)), (np.int64(130), np.int64(188)), (np.int64(126), np.int64(199)), (np.int64(118), np.int64(195)), (np.int64(28), np.int64(268)), (np.int64(128), np.int64(190)), (np.int64(29), np.int64(269)), (np.int64(125), np.int64(185)), (np.int64(126), np.int64(192)), (np.int64(118), np.int64(197)), (np.int64(122), np.int64(197)), (np.int64(124), np.int64(197)), (np.int64(115), np.int64(194)), (np.int64(126), np.int64(178)), (np.int64(127), np.int64(177)), (np.int64(127), np.int64(186)), (np.int64(125), np.int64(198)), (np.int64(129), np.int64(189)), (np.int64(122), np.int64(183)), (np.int64(123), np.int64(182)), (np.int64(17), np.int64(274)), (np.int64(124), np.int64(183)), (np.int64(127), np.int64(179)), (np.int64(119), np.int64(196)), (np.int64(127), np.int64(188)), (np.int64(120), np.int64(204)), (np.int64(123), np.int64(184)), (np.int64(121), np.int64(196)), (np.int64(128), np.int64(192)), (np.int64(18), np.int64(274)), (np.int64(125), np.int64(186)), (np.int64(128), np.int64(178)), (np.int64(115), np.int64(193)), (np.int64(127), np.int64(197)), (np.int64(16), np.int64(274)), (np.int64(29), np.int64(268)), (np.int64(126), np.int64(191)), (np.int64(129), np.int64(190)), (np.int64(123), np.int64(183)), (np.int64(118), np.int64(196)), (np.int64(121), np.int64(195)), (np.int64(114), np.int64(192)), (np.int64(124), np.int64(187)), (np.int64(126), np.int64(184)), (np.int64(118), np.int64(198)), (np.int64(30), np.int64(268)), (np.int64(114), np.int64(194)), (np.int64(127), np.int64(185)), (np.int64(126), np.int64(195)), (np.int64(125), np.int64(197)), (np.int64(116), np.int64(194)), (np.int64(17), np.int64(273)), (np.int64(123), np.int64(199)), (np.int64(127), np.int64(178)), (np.int64(126), np.int64(197)), (np.int64(17), np.int64(275))]

# %% [markdown]
# ## Find best
# No right naswer here, but going to test for a pixel that has at least 3 free neighbors

# %%
# Where the robot is might influence your choice. Shows path to selected point.
robot_start_loc = (60, 40)
best_unseen = find_best_point(im_thresh, all_unseen, robot_loc=robot_start_loc)
assert test_best(im_thresh, best_unseen)

# plot_with_explore_points(im_thresh, zoom=1.0, robot_loc=robot_start_loc, explore_points=all_unseen, best_pt=best_unseen)

path = dijkstra(im_thresh, robot_start_loc, best_unseen, method="A*")
plot_with_path(im_thresh, zoom=1.0, robot_loc=robot_start_loc, goal_loc=best_unseen, path=path)

# %%
grader.check("find_best")
# Out:
# find_best results: All test cases passed!

# %% [markdown]
# # Run waypoint generation on a pretend SLAM map
# Note: This code assumes you have the previous problem completed

# %%
path = dijkstra(im_thresh, robot_start_loc, best_unseen)
waypoints = find_waypoints(im_thresh, path)
plot_with_path(im_thresh, zoom=1.0, robot_loc=robot_start_loc, goal_loc=best_unseen, path=waypoints)
print(f"Waypoints has {len(waypoints)} points of {len(path)}")
# Out:
# Waypoints has 4 points of 141

# %%
# way for me to visualize the waypoints - just plot them as red dots on top of the path
new_rob_start_loc = (200, 50)
all_unseen = find_all_possible_goals(im_thresh)
best_unseen = find_best_point(im_thresh, all_unseen, robot_loc=new_rob_start_loc)
path = dijkstra(im_thresh, new_rob_start_loc, best_unseen, method="A*")
print(len(path))
waypoints = find_waypoints(im_thresh, path)
plot_goal_pts_explore_pts(im_thresh, zoom=1.0, robot_loc=new_rob_start_loc, goal_loc=best_unseen, path=path, goal_pts=waypoints, explore_points=all_unseen, best_pt=best_unseen)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 5
#       3 all_unseen = find_all_possible_goals(im_thresh)
#       4 best_unseen = find_best_point(im_thresh, all_unseen, robot_loc=new_rob_start_loc)
# ----> 5 path = dijkstra(im_thresh, new_rob_start_loc, best_unseen, method="A*")
#       6 print(len(path))
#       7 waypoints = find_waypoints(im_thresh, path)
#
# File ~/Desktop/CodingProjects/ROB456-Final-MEC/ros_ws/src/lab3/lab3/path_planning.py:177, in dijkstra(im, robot_loc, goal_loc, method, return_num_visited)
#     174     raise IndexError(f"ERROR: Goal location {robot_loc} is not in map {im.shape}")
#     176 if not is_reachable(im, robot_loc):
# --> 177     raise ValueError(f"ERROR: Start location {robot_loc} is not in the free space of the map")
#     179 if not is_reachable(im, goal_loc):
#     180     raise ValueError(f"ERROR: Goal location {goal_loc} is not in the free space of the map")
#
# ValueError: ERROR: Start location (200, 50) is not in the free space of the map

# %%
# My very thorough testing!
list_rob_start_locs = [(250, 125), (305, 190), (300, 122), (200, 175), (95, 150)]
all_unseen = find_all_possible_goals(im_thresh)
better_pts = find_best_points(im_thresh, all_unseen)
for new_rob_start_loc in list_rob_start_locs:
    best_unseen = find_best_point(im_thresh, all_unseen, robot_loc=new_rob_start_loc)
    path = dijkstra(im_thresh, new_rob_start_loc, best_unseen, method="A*")
    waypoints = find_waypoints(im_thresh, path)
    plot_goal_pts_explore_pts(im_thresh, zoom=1.0, robot_loc=new_rob_start_loc, goal_loc=best_unseen, path=path, goal_pts=waypoints, explore_points=better_pts, best_pt=best_unseen)

# %%
grader.check("Waypoints")

# %% [markdown]
# ## Hours and collaborators
# Required for every assignment - fill out before you hand-in.
#
# Listing names and websites helps you to document who you worked with and what internet help you received in the case of any plagiarism issues. You should list names of anyone (in class or not) who has substantially helped you with an assignment - or anyone you have *helped*. You do not need to list TAs.
#
# Listing hours helps us track if the assignments are too long.

# %%
# List of names (creates a set)
worked_with_names = {"none"}
# List of URLS W26 (creates a set)
websites = {"none"}
# Approximate number of hours, including lab/in-class time
hours = 5.6 + np.random.uniform()*3.2
print(f"Hours spent: {hours:.2f}")

# %%
grader.check("hours_collaborators")

# %% [markdown]
# ### To submit
#
# - Do a restart then run all to make sure everything runs ok
# - Save the file
# - Submit this .ipynb file and **path_planning.py** and **exploring.py** through gradescope, Lab 4: Explore
# - You do NOT need to submit the data files - we will supply those
# - Take out/suppress all print statements
#
# If the Gradescope autograder fails, please check here first for common reasons for it to fail
#     https://docs.google.com/presentation/d/1tYa5oycUiG4YhXUq5vHvPOpWJ4k_xUPp2rUNIL7Q9RI/edit?usp=sharing
#
# Most likely failure for this assignment is not naming the data directory and files correctly; capitalization matters for the Gradescope grader.
#
# Second most likely failure is because your code ran very, very slowly and the autograder timed out.
#
# Third reason for failure is you forgot to include **path_planning.py** and **exploring.py** and/or you put the file(s) in a folder
